# %%
import pandas as pd
import numpy as np
file_path = '../Data/data.csv'
from data_pre_processing import *
# Out:
# /Users/michael/Documents/CityU/Intern/Y-intercept/Stock-Strategy-Y-intercept/Codes/data_pre_processing.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_his['date'] = ticker_his['date'].apply(lambda x: time.strptime(x, '%Y-%m-%d'))

# %%
file_path = '../Data/data.csv'
stocks = StockData(file_path)
all_his_of_tickers = stocks.all_his_of_tickers()
# Out:
# /Users/michael/Documents/CityU/Intern/Y-intercept/Stock-Strategy-Y-intercept/Codes/data_pre_processing.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_his['date'] = ticker_his['date'].apply(lambda x: time.strptime(x, '%Y-%m-%d'))

# %%
stocks.plot_ts_of_tickers(['1332 JT',
 '1333 JT',
 '1334 JT',
 '1605 JT'])

# %%
tickers = set(list(all_data['ticker']))

# %%
tickers
# Out:
# {'1332 JT',
#  '1333 JT',
#  '1334 JT',
#  '1605 JT',
#  '1721 JT',
#  '1801 JT',
#  '1802 JT',
#  '1803 JT',
#  '1808 JT',
#  '1812 JT',
#  '1925 JT',
#  '1928 JT',
#  '1963 JT',
#  '2002 JT',
#  '2269 JT',
#  '2282 JT',
#  '2413 JT',
#  '2432 JT',
#  '2501 JT',
#  '2502 JT',
#  '2503 JT',
#  '2531 JT',
#  '2768 JT',
#  '2801 JT',
#  '2802 JT',
#  '2871 JT',
#  '2914 JT',
#  '3086 JT',
#  '3099 JT',
#  '3101 JT',
#  '3103 JT',
#  '3105 JT',
#  '3110 JT',
#  '3289 JT',
#  '3382 JT',
#  '3401 JT',
#  '3402 JT',
#  '3405 JT',
#  '3407 JT',
#  '3436 JT',
#  '3659 JT',
#  '3861 JT',
#  '3863 JT',
#  '3864 JT',
#  '3865 JT',
#  '3893 JT',
#  '4004 JT',
#  '4005 JT',
#  '4021 JT',
#  '4041 JT',
#  '4042 JT',
#  '4043 JT',
#  '4061 JT',
#  '4063 JT',
#  '4151 JT',
#  '4183 JT',
#  '4188 JT',
#  '4208 JT',
#  '4272 JT',
#  '4324 JT',
#  '4452 JT',
#  '4502 JT',
#  '4503 JT',
#  '4506 JT',
#  '4507 JT',
#  '4519 JT',
#  '4523 JT',
#  '4543 JT',
#  '4568 JT',
#  '4578 JT',
#  '4631 JT',
# ...

# %%
len(tickers)
# Out:
# 248

# %%
import numpy as np
from bvar import bvar
from prior import Uninformative

# Create Testdata
TestData = np.random.standard_normal((150, 4))

# Test uninformative prior
prior1 = Uninformative(TestData, 2, False)
bv = bvar(TestData, prior1)
bv.mcmc(1000, 200, 1)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 0

# %%
all_his_of_tickers['1332 JT']['date']
# Out:
# 0         (2013, 1, 4, 0, 0, 0, 4, 4, -1)
# 1         (2013, 1, 7, 0, 0, 0, 0, 7, -1)
# 2         (2013, 1, 8, 0, 0, 0, 1, 8, -1)
# 3         (2013, 1, 9, 0, 0, 0, 2, 9, -1)
# 4       (2013, 1, 10, 0, 0, 0, 3, 10, -1)
#                       ...
# 2000    (2021, 3, 15, 0, 0, 0, 0, 74, -1)
# 2001    (2021, 3, 16, 0, 0, 0, 1, 75, -1)
# 2002    (2021, 3, 17, 0, 0, 0, 2, 76, -1)
# 2003    (2021, 3, 18, 0, 0, 0, 3, 77, -1)
# 2004    (2021, 3, 19, 0, 0, 0, 4, 78, -1)
# Name: date, Length: 2005, dtype: object

# %%
all_his_of_tickers['1333 JT']['date']
# Out:
# 2005     (2014, 4, 2, 0, 0, 0, 2, 92, -1)
# 2006     (2014, 4, 3, 0, 0, 0, 3, 93, -1)
# 2007     (2014, 4, 4, 0, 0, 0, 4, 94, -1)
# 2008     (2014, 4, 7, 0, 0, 0, 0, 97, -1)
# 2009     (2014, 4, 8, 0, 0, 0, 1, 98, -1)
#                       ...
# 3701    (2021, 3, 15, 0, 0, 0, 0, 74, -1)
# 3702    (2021, 3, 16, 0, 0, 0, 1, 75, -1)
# 3703    (2021, 3, 17, 0, 0, 0, 2, 76, -1)
# 3704    (2021, 3, 18, 0, 0, 0, 3, 77, -1)
# 3705    (2021, 3, 19, 0, 0, 0, 4, 78, -1)
# Name: date, Length: 1701, dtype: object
